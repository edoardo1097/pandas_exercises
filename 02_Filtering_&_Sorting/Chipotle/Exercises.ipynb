# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df_chipo=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %%
df_chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
df_chipo['item_price'] = df_chipo['item_price'].str.replace('$', '', regex=True).astype('float')

# %%
df_chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df_chipo['unit_price'] = df_chipo['item_price']/df_chipo['quantity']

# %%
df_chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %%
df_more = df_chipo.query('item_price > 10')

# %%
df_more
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %%
df_more = df_more.drop_duplicates(subset = 'item_name')

# %%
df_more
# Out:
#       order_id  quantity                     item_name  \
# 4            2         2                  Chicken Bowl
# 7            4         1                 Steak Burrito
# 23          12         1               Chicken Burrito
# 39          19         1                 Barbacoa Bowl
# 57          26         1                Veggie Burrito
# 62          28         1                   Veggie Bowl
# 79          35         1            Chicken Soft Tacos
# 90          40         1                    Steak Bowl
# 93          41         1              Carnitas Burrito
# 97          43         1                 Carnitas Bowl
# 130         57         1              Barbacoa Burrito
# 135         60         2            Chicken Salad Bowl
# 168         75         1         Barbacoa Crispy Tacos
# 186         83         1             Veggie Salad Bowl
# 217         96         2          Chicken Crispy Tacos
# 250        109         1                 Chicken Salad
# ...

# %%
df_more.query('quantity == 1').item_name.nunique()
# Out:
# 21

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
df_chipo['item_name'].nunique()
# Out:
# 50

# %%
df_price = df_chipo.drop_duplicates(subset = 'item_name')

# %%
df_more[['quantity', 'item_name', 'unit_price']]
# Out:
#       quantity                     item_name  unit_price
# 4            2                  Chicken Bowl        8.49
# 7            1                 Steak Burrito       11.75
# 23           1               Chicken Burrito       10.98
# 39           1                 Barbacoa Bowl       11.75
# 57           1                Veggie Burrito       11.25
# 62           1                   Veggie Bowl       11.25
# 79           1            Chicken Soft Tacos       11.25
# 90           1                    Steak Bowl       11.75
# 93           1              Carnitas Burrito       11.75
# 97           1                 Carnitas Bowl       11.75
# 130          1              Barbacoa Burrito       11.75
# 135          2            Chicken Salad Bowl       11.25
# 168          1         Barbacoa Crispy Tacos       11.75
# 186          1             Veggie Salad Bowl       11.25
# 217          2          Chicken Crispy Tacos        8.75
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
df_chipo.sort_values(by="item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
df_chipo.sort_values('item_price', ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
#devo fare una funzione che mi divida item_price per la quantità

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
mask = df_chipo['item_name'] == 'Veggie Salad Bowl'

# %%
df_chipo[mask].sum()
# Out:
# order_id                                                          17303
# quantity                                                             18
# item_name             Veggie Salad BowlVeggie Salad BowlVeggie Salad...
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                        182.5
# dtype: object

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
len (df_chipo.loc[(df_chipo['item_name'] == 'Canned Soda') & (df_chipo['quantity'] > 1)])
# Out:
# 20
