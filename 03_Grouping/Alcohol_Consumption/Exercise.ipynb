# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
df_drinks= pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")

# %%
df_drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
df_drinks.groupby('continent').sum()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  3258              866            862
# AS                  1630             2677            399
# EU                  8720             5965           6400
# OC                  1435              935            570
# SA                  2101             1377            749
#
#            total_litres_of_pure_alcohol
# continent
# AF                                159.4
# AS                                 95.5
# EU                                387.8
# OC                                 54.1
# SA                                 75.7

# %%
df_drinks.groupby('continent').sum()['beer_servings']
# Out:
# continent
# AF    3258
# AS    1630
# EU    8720
# OC    1435
# SA    2101
# Name: beer_servings, dtype: int64

# %%
df_drinks.groupby('continent').sum()['beer_servings'].idxmax()
# Out:
# 'EU'

# %% [markdown]
# #### Porque puedo ver las functions solo despues le primer .????\

# %%
import jedi

# %%
dfg = df_drinks.groupby('continent').describe()

# %%
dfg.

# %%
df_drinks.set_index("country")["beer_servings"]
# Out:
# country
# Afghanistan      0
# Albania         89
# Algeria         25
# Andorra        245
# Angola         217
#               ...
# Venezuela      333
# Vietnam        111
# Yemen            6
# Zambia          32
# Zimbabwe        64
# Name: beer_servings, Length: 193, dtype: int64

# %%
df_drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df_drinks.set_index("country")
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %%
df_drinks.set_index("country")["beer_servings"]
# Out:
# country
# Afghanistan      0
# Albania         89
# Algeria         25
# Andorra        245
# Angola         217
#               ...
# Venezuela      333
# Vietnam        111
# Yemen            6
# Zambia          32
# Zimbabwe        64
# Name: beer_servings, Length: 193, dtype: int64

# %%
df_drinks.set_index("country")["beer_servings"].sort_values(ascending=False)
# Out:
# country
# Namibia           376
# Czech Republic    361
# Gabon             347
# Germany           346
# Lithuania         343
#                  ...
# Mauritania          0
# Somalia             0
# Monaco              0
# Pakistan            0
# Afghanistan         0
# Name: beer_servings, Length: 193, dtype: int64

# %%
df_drinks.set_index("country")["beer_servings"].sort_values(ascending=False).head(1)
# Out:
# country
# Namibia    376
# Name: beer_servings, dtype: int64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
df_c=df_drinks.groupby("continent").describe("wine_servings")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-60f987e64ce2> in <module>
# ----> 1 df_c=df_drinks.groupby("continent").describe("wine_servings")
#
# TypeError: describe() takes 1 positional argument but 2 were given

# %%
df_drinks.groupby("continent").mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001802F1639A0>>

# %%
df_c=df_drinks.groupby("continent")

# %%
df_c["wine_servings"].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
df_c.mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
df_c.median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
df_drinks.spirit_servings.agg(['mean', 'min', 'max'])
# Out:
# mean     80.994819
# min       0.000000
# max     438.000000
# Name: spirit_servings, dtype: float64

# %%
df_drinks.spirit_servings.agg(['mean', 'min', 'max']).to_frame()
# Out:
#       spirit_servings
# mean        80.994819
# min          0.000000
# max        438.000000

# %%
df_hola=df_drinks["spirit_servings"].mean()

# %%
df_hola
# Out:
# 80.99481865284974

# %%
df_ciao=df_drinks["spirit_servings"].min()

# %%
df_ciao
# Out:
# 0

# %%
df_bho=df_drinks["spirit_servings"].max()

# %%
df_bho
# Out:
# 438

# %%
data={"Name":["hola","ciao","bho"]}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    Name
# 0  hola
# 1  ciao
# 2   bho

# %% [markdown]
# #### differencia entre funciones de "df_drinks." y "pd."?? Por ejemplo, porque la class "Dataframe" puedo usarla solo si pongo pd. antes?

# %%
df_spirit= df_drinks.groupby("spirit_servings")

# %%
df_spirit=pd.DataFrame.assign(df_hola)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_6477/1975736899.py in <module>
# ----> 1 df_spirit=pd.DataFrame.assign(df_hola)
#
# NameError: name 'df_hola' is not defined

# %%
data= [["df_hola"],["df_bho"]]
headers=["mean","max"]
df_end= pd.concat(data, axis=0,keys=headers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_6477/1116776766.py in <module>
#       1 data= [["df_hola"],["df_bho"]]
#       2 headers=["mean","max"]
# ----> 3 df_end= pd.concat(data, axis=0,keys=headers)
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ...

# %%
df_spirit= df_drinks.groupby("spirit_servings")

# %%
df_spirit.describe()
# Out:
#                 beer_servings                                                \
#                         count        mean         std    min     25%    50%
# spirit_servings
# 0                        23.0   16.521739   28.471468    0.0    0.00    0.0
# 1                         9.0   33.333333   48.908077    1.0    5.00    9.0
# 2                         7.0   47.285714   39.101212    3.0   24.00   36.0
# 3                         8.0   68.125000  125.322940    1.0   17.25   28.0
# 4                         3.0   17.666667   14.571662    6.0    9.50   13.0
# ...                       ...         ...         ...    ...     ...    ...
# 302                       1.0   93.000000         NaN   93.0   93.00   93.0
# 315                       1.0  171.000000         NaN  171.0  171.00  171.0
# 326                       2.0  124.000000  173.948268    1.0   62.50  124.0
# 373                       1.0  142.000000         NaN  142.0  142.00  142.0
# ...

# %%
df_spirit.max()
# Out:
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_6477/834220919.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df_spirit.max()
#                             country  beer_servings  wine_servings  \
# spirit_servings
# 0                             Yemen             92            233
# 1                       Timor-Leste            147              9
# 2                           Vietnam            111             19
# 3                           Tunisia            376             20
# 4                          Malaysia             34             13
# ...                             ...            ...            ...
# 302                          Guyana             93              1
# 315                       St. Lucia            171             71
# ...
