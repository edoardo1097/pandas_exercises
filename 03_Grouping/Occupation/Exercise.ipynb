# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
df_users= pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep="|")

# %%
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
df_occupation = df_users.groupby("occupation")

# %%
df_occupation.mean()
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
df_users.head(2)
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043

# %%
def male(x):
    if x == 'M':
        return 1
    if x == 'F':
        return 0

# %%
df_users['Male'] = df_users['gender'].apply(male)

# %%
df_users.head(3)
# Out:
#    user_id  age gender  occupation zip_code  Male
# 0        1   24      M  technician    85711     1
# 1        2   53      F       other    94043     0
# 2        3   23      M      writer    32067     1

# %%
m = df_users.groupby('occupation').Male.sum() / df_users.occupation.value_counts() * 100 
m.head(2)
# Out:
# administrator    54.430380
# artist           53.571429
# dtype: float64

# %%
m.sort_values(ascending = False)
# Out:
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# dtype: float64

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
df_occupation['age'].agg([max, min])
# Out:
#                max  min
# occupation
# administrator   70   21
# artist          48   19
# doctor          64   28
# educator        63   23
# engineer        70   22
# entertainment   50   15
# executive       69   22
# healthcare      62   22
# homemaker       50   20
# lawyer          53   21
# librarian       69   23
# marketing       55   24
# none            55   11
# other           64   13
# programmer      63   20
# retired         73   51
# salesman        66   18
# scientist       55   23
# student         42    7
# technician      55   21
# writer          60   18

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
df_og = df_users.groupby(['occupation', 'gender'])
df_og.age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
df_og2 = df_og.agg({'gender': 'count'})

# %%
df_og2
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7
# educator      F           26
#               M           69
# engineer      F            2
#               M           65
# entertainment F            2
#               M           16
# executive     F            3
#               M           29
# healthcare    F           11
#               M            5
# homemaker     F            6
#               M            1
# lawyer        F            2
#               M           10
# librarian     F           29
#               M           22
# marketing     F           10
#               M           16
# none          F            4
#               M            5
# other         F           36
#               M           69
# programmer    F            6
#               M           60
# retired       F            1
# ...

# %%
df_occ = df_users.groupby(['occupation']).agg('count')
df_occ.head(2)
# Out:
#                user_id  age  gender  zip_code  Male
# occupation
# administrator       79   79      79        79    79
# artist              28   28      28        28    28

# %%
gender_occ = df_og2.div(df_occ, level = "occupation") * 100
gender_occ.loc[: , 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...
